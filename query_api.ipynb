# %%
import pandas as pd
from pymongo import MongoClient
import json, requests
import os
from dotenv import load_dotenv
load_dotenv()
import requests
from pandas.io.json import json_normalize

# %%
def getapi(search):
    url = 'https://api.foursquare.com/v2/venues/explore'

    params = dict(
    client_id=os.getenv('Client_ID'),
    client_secret=os.getenv('Client_Sc'),
    v='20180323',
    ll='37.795531,-122.400598',
    query=search,
    limit=1
    )
    resp = requests.get(url=url, params=params)
    data = json.loads(resp.text)
    
    df_api = pd.DataFrame([{
        'Query' : data['response']['query'],
        'Total Results' : data['response']['totalResults'],
        'Name': data['response']['groups'][0]['items'][0]['venue']['name'],
        'Distance' :data['response']['groups'][0]['items'][0]['venue']['location']['distance'],
        'Address': data['response']['groups'][0]['items'][0]['venue']['location']['formattedAddress'][0],
        'Postal Code':data['response']['groups'][0]['items'][0]['venue']['location']['postalCode'],
        'Latitude' : data['response']['suggestedBounds']['ne']['lat'],
        'longitude' : data['response']['suggestedBounds']['ne']['lng']
        
        
        
    }])
    
    return df_api

# %%
df1 = getapi('Primary School')
df1
# Out:
#             Query  Total Results         Name  Distance       Address  \
# 0  primary school              4  HIIT School      1088  345 Spear St
#
#   Postal Code   Latitude   longitude
# 0       94105  37.791415 -122.388978

# %%
df2 = getapi('Starbucks')
df2
# Out:
#        Query  Total Results       Name  Distance                   Address  \
# 0  starbucks             52  Starbucks       174  398 Market St (Front St)
#
#   Postal Code   Latitude   longitude
# 0       94111  37.795749 -122.397875

# %%
df3 = getapi('airport')
df3
# Out:
#      Query  Total Results                                               Name  \
# 0  airport             63  San Francisco International Airport (SFO) (San...
#
#    Distance                      Address Postal Code   Latitude  longitude
# 0     19941  N McDonnell Rd (at Link Rd)       94128  37.618063 -122.38574

# %%
df4 = getapi('veganfood')
df4
# Out:
#        Query  Total Results                               Name  Distance  \
# 0  veganfood              1  Sunny Vibrations Vegan Food Truck      4756
#
#                                  Address Postal Code   Latitude   longitude
# 0  3849 20th St. (btwn Dolores & Church)       94114  37.759512 -122.425471

# %%
df5 = getapi('night club')
df5
# Out:
#         Query  Total Results               Name  Distance  \
# 0  night club             24  Love + Propaganda       928
#
#                     Address Postal Code   Latitude   longitude
# 0  85 Campton Pl (Stockton)       94108  37.790188 -122.405537

# %%
df6= getapi('start ups')
df6
# Out:
#        Query  Total Results           Name  Distance  \
# 0  start ups             47  Filbert Steps       788
#
#                                              Address Postal Code   Latitude  \
# 0  200-224 Filbert St (btw Sansome & Telegraph Hill)       94133  37.803299
#
#     longitude
# 0 -122.403032

# %%
df7= getapi('basketball stadium')
df7
# Out:
#                 Query  Total Results          Name  Distance         Address  \
# 0  basketball stadium              3  Chase Center      3289  1 Warriors Way
#
#   Postal Code   Latitude  longitude
# 0       94158  37.769214 -122.38611

# %%
result = pd.concat([df1, df2, df3,df4,df5,df6,df7], ignore_index=True)
result
# Out:
#                 Query  Total Results  \
# 0      primary school              4
# 1           starbucks             52
# 2             airport             63
# 3           veganfood              1
# 4          night club             24
# 5           start ups             47
# 6  basketball stadium              3
#
#                                                 Name  Distance  \
# 0                                        HIIT School      1088
# 1                                          Starbucks       174
# 2  San Francisco International Airport (SFO) (San...     19941
# 3                  Sunny Vibrations Vegan Food Truck      4756
# 4                                  Love + Propaganda       928
# 5                                      Filbert Steps       788
# 6                                       Chase Center      3289
#
#                                              Address Postal Code   Latitude  \
# 0                                       345 Spear St       94105  37.791415
# 1                           398 Market St (Front St)       94111  37.795749
# 2                        N McDonnell Rd (at Link Rd)       94128  37.618063
# 3              3849 20th St. (btwn Dolores & Church)       94114  37.759512
# 4                           85 Campton Pl (Stockton)       94108  37.790188
# 5  200-224 Filbert St (btw Sansome & Telegraph Hill)       94133  37.803299
# 6                                     1 Warriors Way       94158  37.769214
#
#     longitude
# 0 -122.388978
# 1 -122.397875
# 2 -122.385740
# 3 -122.425471
# 4 -122.405537
# 5 -122.403032
# 6 -122.386110

# %%
result['Distance'] = result['Distance'].apply(lambda x: str(x) + ' miters')

# %%
result
# Out:
#                 Query  Total Results  \
# 0      primary school              4
# 1           starbucks             52
# 2             airport             63
# 3           veganfood              1
# 4          night club             24
# 5           start ups             47
# 6  basketball stadium              3
#
#                                                 Name      Distance  \
# 0                                        HIIT School   1088 miters
# 1                                          Starbucks    174 miters
# 2  San Francisco International Airport (SFO) (San...  19941 miters
# 3                  Sunny Vibrations Vegan Food Truck   4756 miters
# 4                                  Love + Propaganda    928 miters
# 5                                      Filbert Steps    788 miters
# 6                                       Chase Center   3289 miters
#
#                                              Address Postal Code   Latitude  \
# 0                                       345 Spear St       94105  37.791415
# 1                           398 Market St (Front St)       94111  37.795749
# 2                        N McDonnell Rd (at Link Rd)       94128  37.618063
# 3              3849 20th St. (btwn Dolores & Church)       94114  37.759512
# 4                           85 Campton Pl (Stockton)       94108  37.790188
# 5  200-224 Filbert St (btw Sansome & Telegraph Hill)       94133  37.803299
# 6                                     1 Warriors Way       94158  37.769214
#
#     longitude
# 0 -122.388978
# 1 -122.397875
# 2 -122.385740
# 3 -122.425471
# 4 -122.405537
# 5 -122.403032
# 6 -122.386110

# %%
result.to_json("input/employee_needs.json",orient="records")
